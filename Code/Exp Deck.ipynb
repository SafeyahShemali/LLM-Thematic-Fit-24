# %% [markdown]
# ## Expeirments Deck

# %% [markdown]
# ### Dependencies

# %%
import models # class for creating connections with models
import experiments # class of various version of expeiments

# %% [markdown]
# ### Model Creation

# %% [markdown]
# For GPT4-Turbo Model, run the following Code Block:

# %%
# Create The Model API 
model_name = "gpt-4-0125-preview"
model_key = "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"  # the key is private 
model_base_url = "https://api.openai.com/v1"
model_temp = 0.0
model_top_p = 0.95

llama2_model = models.Model(model_name,model_key,model_base_url,model_temp, model_top_p)

# %% [markdown]
# For CodeLLama2-Instruct-13B Model, run the following code block:

# %%
# Create The Model API 
model_name = "codellama/CodeLlama-13b-Instruct-hf"
model_key = "EMPTY"
model_base_url = "http://0.0.0.0:8000/v1"
model_temp = 0.0
model_top_p = 0.95

llama2_model = models.Model(model_name,model_key,model_base_url,model_temp, model_top_p)

# %% [markdown]
# ### Experiments with Lamma Tuple (Exp 1.x)

# %% [markdown]
# - For ferretti Location

# %%
experiments.exp_simple_lemma_tuple_ferretti('ferretti_location.csv','Location', llama2_model ,model_name)
# Out:
# serve library
# user_prompt :  Given the predicate 'serve', how much does the argument 'library' fit the role of Location? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "Medium"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# user_prompt :  Given the predicate 'serve', how much does the argument 'library' fit the role of Location? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "0.7"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]

# %% [markdown]
# - For ferretti Instrument

# %%
experiments.exp_simple_lemma_tuple_ferretti('ferretti_instrument.csv','Instrument', llama2_model ,model_name)

# %% [markdown]
# - For Pado

# %%
experiments.exp_simple_lemma_tuple_other('pado_plausibility_pb.txt', llama2_model ,model_name)
# Out:
# New Record :  advise banker
# user_prompt :  Given the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "High"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# user_prompt :  Given the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "0.8"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]

# %% [markdown]
# - For Mcrae

# %%
experiments.exp_simple_lemma_tuple_other('mcrae_agent_patient_more.txt', llama2_model ,model_name)
# Out:
# New Record :  abandon baby
# user_prompt :  Given the predicate 'abandon', how much does the argument 'baby' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "Low"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# user_prompt :  Given the predicate 'abandon', how much does the argument 'baby' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "0.1"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]

# %% [markdown]
# ### Experiments with Generated Sentences (Exp 2.x)

# %% [markdown]
# - For ferretti Location

# %%
experiments.exp_simple_gen_sentences_ferretti('ferretti_location.csv','Location', llama2_model, model_name)
# Out:
# New Record :  serve library
# user_prompt :  Generate five semantically coherent sentences with the predicate 'serve', argument 'library', and the role of Location Reply only with a valid JSON dictionary containing the key "Sentences" and a value that is a list of five semantically coherent sentences, each with the given predicate, argument, and role according to the following structure {"Sentences": String}. Avoid adding any text outside this JSON dictionary.
# response_sentences:  ```json
# {
#   "Sentences": [
#     "The community center will serve as a library for the neighborhood.",
#     "In times of crisis, the school's gymnasium will serve as a library to ensure access to information.",
#     "The old train station has been renovated to serve as a library, blending history with literacy.",
#     "A mobile van has been outfitted to serve as a library, bringing books to remote areas.",
#     "The vacant lot next to the park will soon serve as a library, providing a new hub for learning."
#   ]
# }
# ```
# sentences:  ['The community center will serve as a library for the neighborhood.', "In times of crisis, the school's gymnasium will serve as a library to ensure access to information.", 'The old train station has been renovated to serve as a library, blending history with literacy.', 'A mobile van has been outfitted to serve as a library, bringing books to remote areas.', 'The vacant lot next to the park will soon serve as a library, providing a new hub for learning.']
# The sentences are:  ['The community center will serve as a library for the neighborhood.', "In times of crisis, the school's gymnasium will serve as a library to ensure access to information.", 'The old train station has been renovated to serve as a library, blending history with literacy.', 'A mobile van has been outfitted to serve as a library, bringing books to remote areas.', 'The vacant lot next to the park will soon serve as a library, providing a new hub for learning.']
# check_semantic_prompt :  Is the given sentence 'The community center will serve as a library for the neighborhood.' semantically coherent and containing the predicate 'serve' and the argument 'library' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value 'Yes' or 'No', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.
# response_check_semantic:  {"Is Semantically Coherent": "No"}
# is_semantic:  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The community center will serve as a library for the neighborhood.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'No'}]
# categorical from prevL  ['serve', 'library', '2.4', '0.5']
# Numerical from prev:  ['serve', 'library', '2.4', '0.7']
# After Poping the semantic:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# check_semantic_prompt :  Is the given sentence 'In times of crisis, the school's gymnasium will serve as a library to ensure access to information.' semantically coherent and containing the predicate 'serve' and the argument 'library' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value 'Yes' or 'No', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.
# response_check_semantic:  {"Is Semantically Coherent": "Yes"}
# is_semantic:  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# user_prompt :  Given the following sentence 'In times of crisis, the school's gymnasium will serve as a library to ensure access to information.', for the predicate 'serve', how much does the argument 'library' fit the role of Location? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "High"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# categorical_with_senetence:  0.75
# user_prompt :  Given the following sentence 'In times of crisis, the school's gymnasium will serve as a library to ensure access to information.', for the predicate 'serve', how much does the argument 'library' fit the role of Location? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "0.8"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# numerical_with_senetence:  0.8
# After Poping the semantic:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# check_semantic_prompt :  Is the given sentence 'The old train station has been renovated to serve as a library, blending history with literacy.' semantically coherent and containing the predicate 'serve' and the argument 'library' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value 'Yes' or 'No', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.
# response_check_semantic:  {"Is Semantically Coherent": "Yes"}
# is_semantic:  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The old train station has been renovated to serve as a library, blending history with literacy.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# user_prompt :  Given the following sentence 'The old train station has been renovated to serve as a library, blending history with literacy.', for the predicate 'serve', how much does the argument 'library' fit the role of Location? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "Near-Perfect"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The old train station has been renovated to serve as a library, blending history with literacy.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# categorical_with_senetence:  1.0
# user_prompt :  Given the following sentence 'The old train station has been renovated to serve as a library, blending history with literacy.', for the predicate 'serve', how much does the argument 'library' fit the role of Location? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "1.0"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The old train station has been renovated to serve as a library, blending history with literacy.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# numerical_with_senetence:  1.0
# After Poping the semantic:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# check_semantic_prompt :  Is the given sentence 'A mobile van has been outfitted to serve as a library, bringing books to remote areas.' semantically coherent and containing the predicate 'serve' and the argument 'library' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value 'Yes' or 'No', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.
# response_check_semantic:  {"Is Semantically Coherent": "No"}
# is_semantic:  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'A mobile van has been outfitted to serve as a library, bringing books to remote areas.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'No'}]
# categorical from prevL  ['serve', 'library', '2.4', '0.5']
# Numerical from prev:  ['serve', 'library', '2.4', '0.7']
# After Poping the semantic:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# check_semantic_prompt :  Is the given sentence 'The vacant lot next to the park will soon serve as a library, providing a new hub for learning.' semantically coherent and containing the predicate 'serve' and the argument 'library' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value 'Yes' or 'No', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.
# response_check_semantic:  {"Is Semantically Coherent": "Yes"}
# is_semantic:  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The vacant lot next to the park will soon serve as a library, providing a new hub for learning.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# user_prompt :  Given the following sentence 'The vacant lot next to the park will soon serve as a library, providing a new hub for learning.', for the predicate 'serve', how much does the argument 'library' fit the role of Location? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "Near-Perfect"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The vacant lot next to the park will soon serve as a library, providing a new hub for learning.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# categorical_with_senetence:  1.0
# user_prompt :  Given the following sentence 'The vacant lot next to the park will soon serve as a library, providing a new hub for learning.', for the predicate 'serve', how much does the argument 'library' fit the role of Location? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "0.9"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The vacant lot next to the park will soon serve as a library, providing a new hub for learning.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# numerical_with_senetence:  0.9
# After Poping the semantic:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# result1:  ['serve', 'library', '', 0.7, "In times of crisis, the school's gymnasium will serve as a library to ensure access to information.", 0.8, 'The old train station has been renovated to serve as a library, blending history with literacy.', 1.0, '', 0.7, 'The vacant lot next to the park will soon serve as a library, providing a new hub for learning.', 0.9, '2.4', 0.82]
# result2:  ['serve', 'library', '', 0.5, "In times of crisis, the school's gymnasium will serve as a library to ensure access to information.", 0.75, 'The old train station has been renovated to serve as a library, blending history with literacy.', 1.0, '', 0.5, 'The vacant lot next to the park will soon serve as a library, providing a new hub for learning.', 1.0, '2.4', 0.75]
# ---------------------DONE----------------------

# %% [markdown]
# - For ferretti Instrument

# %%
experiments.exp_simple_gen_sentences_ferretti('ferretti_instrument.csv','Instrument', llama2_model, model_name)

# %% [markdown]
# - For Pado

# %%
experiments.exp_simple_gen_sentences_other('pado_plausibility_pb.txt', llama2_model ,model_name)
# Out:
# New Record :  advise banker
# user_prompt :  Generate five semantically coherent sentences with the predicate 'advise', argument 'banker', and the role of ARG0 Reply only with a valid JSON dictionary containing the key "Sentences" and a value that is a list of five semantically coherent sentences, each with the given predicate, argument, and role according to the following structure {"Sentences": String}. Avoid adding any text outside this JSON dictionary.
# response_sentences:  ```json
# {
#   "Sentences": [
#     "The banker advised the client on the best investment strategies.",
#     "A banker advised her to reconsider the loan terms before proceeding.",
#     "Before making any decisions, the banker advised looking into more sustainable financial plans.",
#     "Upon reviewing her account, the banker advised increasing the savings contributions.",
#     "The banker advised against withdrawing the fixed deposit prematurely."
#   ]
# }
# ```
# sentences:  ['The banker advised the client on the best investment strategies.', 'A banker advised her to reconsider the loan terms before proceeding.', 'Before making any decisions, the banker advised looking into more sustainable financial plans.', 'Upon reviewing her account, the banker advised increasing the savings contributions.', 'The banker advised against withdrawing the fixed deposit prematurely.']
# The sentences are:  ['The banker advised the client on the best investment strategies.', 'A banker advised her to reconsider the loan terms before proceeding.', 'Before making any decisions, the banker advised looking into more sustainable financial plans.', 'Upon reviewing her account, the banker advised increasing the savings contributions.', 'The banker advised against withdrawing the fixed deposit prematurely.']
# check_semantic_prompt :  Is the given sentence 'The banker advised the client on the best investment strategies.' semantically coherent and containing the predicate 'advise' and the argument 'banker' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value 'Yes' or 'No', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.
# response_check_semantic:  {"Is Semantically Coherent": "Yes"}
# is_semantic:  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The banker advised the client on the best investment strategies.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# user_prompt :  Given the following sentence 'The banker advised the client on the best investment strategies.', for the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "Near-Perfect"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The banker advised the client on the best investment strategies.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# categorical_with_senetence:  1.0
# user_prompt :  Given the following sentence 'The banker advised the client on the best investment strategies.', for the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "1.0"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The banker advised the client on the best investment strategies.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# numerical_with_senetence:  1.0
# After Poping the semantic:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# check_semantic_prompt :  Is the given sentence 'A banker advised her to reconsider the loan terms before proceeding.' semantically coherent and containing the predicate 'advise' and the argument 'banker' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value 'Yes' or 'No', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.
# response_check_semantic:  {"Is Semantically Coherent": "Yes"}
# is_semantic:  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'A banker advised her to reconsider the loan terms before proceeding.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# user_prompt :  Given the following sentence 'A banker advised her to reconsider the loan terms before proceeding.', for the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "High"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'A banker advised her to reconsider the loan terms before proceeding.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# categorical_with_senetence:  0.75
# user_prompt :  Given the following sentence 'A banker advised her to reconsider the loan terms before proceeding.', for the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "0.9"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'A banker advised her to reconsider the loan terms before proceeding.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# numerical_with_senetence:  0.9
# After Poping the semantic:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# check_semantic_prompt :  Is the given sentence 'Before making any decisions, the banker advised looking into more sustainable financial plans.' semantically coherent and containing the predicate 'advise' and the argument 'banker' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value 'Yes' or 'No', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.
# response_check_semantic:  {"Is Semantically Coherent": "Yes"}
# is_semantic:  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'Before making any decisions, the banker advised looking into more sustainable financial plans.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# user_prompt :  Given the following sentence 'Before making any decisions, the banker advised looking into more sustainable financial plans.', for the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "Near-Perfect"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'Before making any decisions, the banker advised looking into more sustainable financial plans.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# categorical_with_senetence:  1.0
# user_prompt :  Given the following sentence 'Before making any decisions, the banker advised looking into more sustainable financial plans.', for the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "1.0"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'Before making any decisions, the banker advised looking into more sustainable financial plans.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# numerical_with_senetence:  1.0
# After Poping the semantic:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# check_semantic_prompt :  Is the given sentence 'Upon reviewing her account, the banker advised increasing the savings contributions.' semantically coherent and containing the predicate 'advise' and the argument 'banker' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value 'Yes' or 'No', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.
# response_check_semantic:  {"Is Semantically Coherent": "Yes"}
# is_semantic:  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'Upon reviewing her account, the banker advised increasing the savings contributions.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# user_prompt :  Given the following sentence 'Upon reviewing her account, the banker advised increasing the savings contributions.', for the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "Near-Perfect"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'Upon reviewing her account, the banker advised increasing the savings contributions.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# categorical_with_senetence:  1.0
# user_prompt :  Given the following sentence 'Upon reviewing her account, the banker advised increasing the savings contributions.', for the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "1.0"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'Upon reviewing her account, the banker advised increasing the savings contributions.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# numerical_with_senetence:  1.0
# After Poping the semantic:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# check_semantic_prompt :  Is the given sentence 'The banker advised against withdrawing the fixed deposit prematurely.' semantically coherent and containing the predicate 'advise' and the argument 'banker' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value 'Yes' or 'No', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.
# response_check_semantic:  {"Is Semantically Coherent": "Yes"}
# is_semantic:  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The banker advised against withdrawing the fixed deposit prematurely.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# user_prompt :  Given the following sentence 'The banker advised against withdrawing the fixed deposit prematurely.', for the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "Near-Perfect"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The banker advised against withdrawing the fixed deposit prematurely.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# categorical_with_senetence:  1.0
# user_prompt :  Given the following sentence 'The banker advised against withdrawing the fixed deposit prematurely.', for the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "1.0"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The banker advised against withdrawing the fixed deposit prematurely.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# numerical_with_senetence:  1.0
# After Poping the semantic:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# result1:  ['advise', 'banker', 'ARG0', 'The banker advised the client on the best investment strategies.', 1.0, 'A banker advised her to reconsider the loan terms before proceeding.', 0.9, 'Before making any decisions, the banker advised looking into more sustainable financial plans.', 1.0, 'Upon reviewing her account, the banker advised increasing the savings contributions.', 1.0, 'The banker advised against withdrawing the fixed deposit prematurely.', 1.0, '6.0\n', 0.98]
# result2:  ['advise', 'banker', 'ARG0', 'The banker advised the client on the best investment strategies.', 1.0, 'A banker advised her to reconsider the loan terms before proceeding.', 0.75, 'Before making any decisions, the banker advised looking into more sustainable financial plans.', 1.0, 'Upon reviewing her account, the banker advised increasing the savings contributions.', 1.0, 'The banker advised against withdrawing the fixed deposit prematurely.', 1.0, '6.0\n', 0.95]
# ---------------------DONE----------------------

# %% [markdown]
# - For Mcrae

# %%
experiments.exp_simple_gen_sentences_other('mcrae_agent_patient_more.txt', llama2_model ,model_name)

# %% [markdown]
# ### Experiments with Lamma Tuple and Reasoning (Exp 3.x)

# %% [markdown]
# - For ferretti Location

# %%
experiments.exp_reasoning_lemma_tuple_ferretti('ferretti_location.csv', 'Location', llama2_model ,model_name)
# Out:
# New Record :  serve library
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_reason:
#  {"Response": "The PropBank Location role for the predicate 'serve' typically refers to the place or environment where the service is provided or takes place. This could include physical locations such as a restaurant, a school, or a geographical area, as well as more abstract locations like a website or a network where services are rendered. The key properties should involve specificity to the context of the service being provided, indicating where the action of serving is occurring."}
# join reasons:  ['serve', 'library', 'Location', "The PropBank Location role for the predicate 'serve' typically refers to the place or environment where the service is provided or takes place. This could include physical locations such as a restaurant, a school, or a geographical area, as well as more abstract locations like a website or a network where services are rendered. The key properties should involve specificity to the context of the service being provided, indicating where the action of serving is occurring."]
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should its PropBank Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The PropBank Location role for the predicate 'serve' typically refers to the place or environment where the service is provided or takes place. This could include physical locations such as a restaurant, a school, or a geographical area, as well as more abstract locations like a website or a network where services are rendered. The key properties should involve specificity to the context of the service being provided, indicating where the action of serving is occurring."}]
# response_reason:
#  {"Response": "The argument 'library' as related to the predicate 'serve' has properties indicating it as a physical location where services such as lending books, providing information, and offering a space for study and research are provided. It suggests a context of serving knowledge, resources, or space to patrons or the community."}
# join reasons:  ['serve', 'library', 'Location', "The PropBank Location role for the predicate 'serve' typically refers to the place or environment where the service is provided or takes place. This could include physical locations such as a restaurant, a school, or a geographical area, as well as more abstract locations like a website or a network where services are rendered. The key properties should involve specificity to the context of the service being provided, indicating where the action of serving is occurring.", "The argument 'library' as related to the predicate 'serve' has properties indicating it as a physical location where services such as lending books, providing information, and offering a space for study and research are provided. It suggests a context of serving knowledge, resources, or space to patrons or the community."]
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should its PropBank Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The PropBank Location role for the predicate 'serve' typically refers to the place or environment where the service is provided or takes place. This could include physical locations such as a restaurant, a school, or a geographical area, as well as more abstract locations like a website or a network where services are rendered. The key properties should involve specificity to the context of the service being provided, indicating where the action of serving is occurring."}, {'role': 'user', 'content': 'Given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' as related to the predicate 'serve' has properties indicating it as a physical location where services such as lending books, providing information, and offering a space for study and research are provided. It suggests a context of serving knowledge, resources, or space to patrons or the community."}]
# response_reason:
#  {"Response": "The argument 'library' fits well with the PropBank Location role for the predicate 'serve', as it specifies the physical location where services are provided, aligning with the expected properties of a location where serving occurs."}
# join reasons:  ['serve', 'library', 'Location', "The PropBank Location role for the predicate 'serve' typically refers to the place or environment where the service is provided or takes place. This could include physical locations such as a restaurant, a school, or a geographical area, as well as more abstract locations like a website or a network where services are rendered. The key properties should involve specificity to the context of the service being provided, indicating where the action of serving is occurring.", "The argument 'library' as related to the predicate 'serve' has properties indicating it as a physical location where services such as lending books, providing information, and offering a space for study and research are provided. It suggests a context of serving knowledge, resources, or space to patrons or the community.", "The argument 'library' fits well with the PropBank Location role for the predicate 'serve', as it specifies the physical location where services are provided, aligning with the expected properties of a location where serving occurs."]
# user_prompt :  Given the predicate 'serve', how much does the argument 'library' fit the role of Location? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "High"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should its PropBank Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The PropBank Location role for the predicate 'serve' typically refers to the place or environment where the service is provided or takes place. This could include physical locations such as a restaurant, a school, or a geographical area, as well as more abstract locations like a website or a network where services are rendered. The key properties should involve specificity to the context of the service being provided, indicating where the action of serving is occurring."}, {'role': 'user', 'content': 'Given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' as related to the predicate 'serve' has properties indicating it as a physical location where services such as lending books, providing information, and offering a space for study and research are provided. It suggests a context of serving knowledge, resources, or space to patrons or the community."}, {'role': 'user', 'content': 'Given the above, how will the argument \'library\' fit the PropBank Location role for the predicate \'serve\'? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' fits well with the PropBank Location role for the predicate 'serve', as it specifies the physical location where services are provided, aligning with the expected properties of a location where serving occurs."}]
# categorical score:  0.75
# user_prompt :  Given the predicate 'serve', how much does the argument 'library' fit the role of Location? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "0.9"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'serve\', what properties should its PropBank Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The PropBank Location role for the predicate 'serve' typically refers to the place or environment where the service is provided or takes place. This could include physical locations such as a restaurant, a school, or a geographical area, as well as more abstract locations like a website or a network where services are rendered. The key properties should involve specificity to the context of the service being provided, indicating where the action of serving is occurring."}, {'role': 'user', 'content': 'Given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' as related to the predicate 'serve' has properties indicating it as a physical location where services such as lending books, providing information, and offering a space for study and research are provided. It suggests a context of serving knowledge, resources, or space to patrons or the community."}, {'role': 'user', 'content': 'Given the above, how will the argument \'library\' fit the PropBank Location role for the predicate \'serve\'? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' fits well with the PropBank Location role for the predicate 'serve', as it specifies the physical location where services are provided, aligning with the expected properties of a location where serving occurs."}]
# numerical score:  0.9

# %% [markdown]
# - For ferretti Instrument

# %%
experiments.exp_reasoning_lemma_tuple_ferretti('ferretti_instrument.csv', 'Instrument', llama2_model ,model_name)

# %% [markdown]
# - For Pado

# %%
experiments.exp_reasoning_lemma_tuple_other('pado_plausibility_pb.txt', llama2_model ,model_name)
# Out:
# New Record :  advise banker
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# response_reason:
#  {"Response": "The PropBank ARG0 role for the predicate 'advise' should have the properties of being an advisor or someone who gives advice."}
# join reasons:  ['advise', 'banker', 'ARG0', "The PropBank ARG0 role for the predicate 'advise' should have the properties of being an advisor or someone who gives advice."]
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The PropBank ARG0 role for the predicate 'advise' should have the properties of being an advisor or someone who gives advice."}]
# response_reason:
#  {"Response": "The argument 'banker' has the relevant properties of being capable of giving financial advice, expertise in financial matters, and potentially acting in an advisory capacity to clients."}
# join reasons:  ['advise', 'banker', 'ARG0', "The PropBank ARG0 role for the predicate 'advise' should have the properties of being an advisor or someone who gives advice.", "The argument 'banker' has the relevant properties of being capable of giving financial advice, expertise in financial matters, and potentially acting in an advisory capacity to clients."]
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The PropBank ARG0 role for the predicate 'advise' should have the properties of being an advisor or someone who gives advice."}, {'role': 'user', 'content': 'Given the predicate \'advise\', and the argument \'banker\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' has the relevant properties of being capable of giving financial advice, expertise in financial matters, and potentially acting in an advisory capacity to clients."}]
# response_reason:
#  {"Response": "The argument 'banker' fits well with the PropBank ARG0 role for the predicate 'advise', as it embodies the properties of being an advisor, specifically in financial matters, which is a common context for advice."}
# join reasons:  ['advise', 'banker', 'ARG0', "The PropBank ARG0 role for the predicate 'advise' should have the properties of being an advisor or someone who gives advice.", "The argument 'banker' has the relevant properties of being capable of giving financial advice, expertise in financial matters, and potentially acting in an advisory capacity to clients.", "The argument 'banker' fits well with the PropBank ARG0 role for the predicate 'advise', as it embodies the properties of being an advisor, specifically in financial matters, which is a common context for advice."]
# Conversation Before the fit scoring:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The PropBank ARG0 role for the predicate 'advise' should have the properties of being an advisor or someone who gives advice."}, {'role': 'user', 'content': 'Given the predicate \'advise\', and the argument \'banker\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' has the relevant properties of being capable of giving financial advice, expertise in financial matters, and potentially acting in an advisory capacity to clients."}, {'role': 'user', 'content': 'Given the above, how will the argument \'banker\' fit the PropBank ARG0 role for the predicate \'advise\'? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' fits well with the PropBank ARG0 role for the predicate 'advise', as it embodies the properties of being an advisor, specifically in financial matters, which is a common context for advice."}]
# user_prompt :  Given the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "High"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The PropBank ARG0 role for the predicate 'advise' should have the properties of being an advisor or someone who gives advice."}, {'role': 'user', 'content': 'Given the predicate \'advise\', and the argument \'banker\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' has the relevant properties of being capable of giving financial advice, expertise in financial matters, and potentially acting in an advisory capacity to clients."}, {'role': 'user', 'content': 'Given the above, how will the argument \'banker\' fit the PropBank ARG0 role for the predicate \'advise\'? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' fits well with the PropBank ARG0 role for the predicate 'advise', as it embodies the properties of being an advisor, specifically in financial matters, which is a common context for advice."}]
# user_prompt :  Given the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "0.9"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The PropBank ARG0 role for the predicate 'advise' should have the properties of being an advisor or someone who gives advice."}, {'role': 'user', 'content': 'Given the predicate \'advise\', and the argument \'banker\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' has the relevant properties of being capable of giving financial advice, expertise in financial matters, and potentially acting in an advisory capacity to clients."}, {'role': 'user', 'content': 'Given the above, how will the argument \'banker\' fit the PropBank ARG0 role for the predicate \'advise\'? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' fits well with the PropBank ARG0 role for the predicate 'advise', as it embodies the properties of being an advisor, specifically in financial matters, which is a common context for advice."}]

# %% [markdown]
# - For Mcrae

# %%
experiments.exp_reasoning_lemma_tuple_other('mcrae_agent_patient_more.txt', llama2_model ,model_name)

# %% [markdown]
# ### Experiments with Generated Sentences and Reasoning (Exp 4.x)

# %% [markdown]
# - For ferretti Location

# %%
experiments.exp_reasoning_gen_sentences_ferretti('ferretti_location.csv','Location', llama2_model, model_name)
# Out:
# New Record :  serve library
# The sentences are:  ['The community center will serve as a library for the neighborhood.', "In times of crisis, the school's gymnasium will serve as a library to ensure access to information.", 'The old train station has been renovated to serve as a library, blending history with literacy.', 'A mobile van has been outfitted to serve as a library, bringing books to remote areas.', 'The vacant lot next to the park will soon serve as a library, providing a new hub for learning.']
# check_semantic_prompt :  Is the given sentence 'The community center will serve as a library for the neighborhood.' semantically coherent and containing the predicate 'serve' and the argument 'library' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value 'Yes' or 'No', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.
# response_check_semantic:  {"Is Semantically Coherent": "No"}
# responce:  {"Is Semantically Coherent": "No"}
# is_semantic:  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The community center will serve as a library for the neighborhood.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'No'}]
# categorical from prevL  ['serve', 'library', '2.4', '0.75']
# Numerical from prev:  ['serve', 'library', '2.4', '0.9']
# After Poping the semantic:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# check_semantic_prompt :  Is the given sentence 'In times of crisis, the school's gymnasium will serve as a library to ensure access to information.' semantically coherent and containing the predicate 'serve' and the argument 'library' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value 'Yes' or 'No', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.
# response_check_semantic:  {"Is Semantically Coherent": "Yes"}
# responce:  {"Is Semantically Coherent": "Yes"}
# is_semantic:  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# response_reason:
#  {"Response": "The Location role should have properties indicating it is a physical space capable of being repurposed or used for an activity different from its original function, specifically to facilitate access to information or act as a place for reading and studying."}
# responce:  {"Response": "The Location role should have properties indicating it is a physical space capable of being repurposed or used for an activity different from its original function, specifically to facilitate access to information or act as a place for reading and studying."}
# join reasons:  ['serve', 'library', 'Location', 'The Location role should have properties indicating it is a physical space capable of being repurposed or used for an activity different from its original function, specifically to facilitate access to information or act as a place for reading and studying.']
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space capable of being repurposed or used for an activity different from its original function, specifically to facilitate access to information or act as a place for reading and studying.'}]
# response_reason:
#  {"Response": "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, and it implies a setting conducive to study and learning."}
# responce:  {"Response": "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, and it implies a setting conducive to study and learning."}
# join reasons:  ['serve', 'library', 'Location', 'The Location role should have properties indicating it is a physical space capable of being repurposed or used for an activity different from its original function, specifically to facilitate access to information or act as a place for reading and studying.', "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, and it implies a setting conducive to study and learning."]
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space capable of being repurposed or used for an activity different from its original function, specifically to facilitate access to information or act as a place for reading and studying.'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, and it implies a setting conducive to study and learning."}]
# response_reason:
#  {"Response": "The argument 'library' fits the Location role for the predicate 'serve' by indicating that the gymnasium will be repurposed as a space for accessing information, akin to the functions of a library, thus making it a suitable location for this new role."}
# responce:  {"Response": "The argument 'library' fits the Location role for the predicate 'serve' by indicating that the gymnasium will be repurposed as a space for accessing information, akin to the functions of a library, thus making it a suitable location for this new role."}
# join reasons:  ['serve', 'library', 'Location', 'The Location role should have properties indicating it is a physical space capable of being repurposed or used for an activity different from its original function, specifically to facilitate access to information or act as a place for reading and studying.', "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, and it implies a setting conducive to study and learning.", "The argument 'library' fits the Location role for the predicate 'serve' by indicating that the gymnasium will be repurposed as a space for accessing information, akin to the functions of a library, thus making it a suitable location for this new role."]
# user_prompt :  Given the following sentence 'In times of crisis, the school's gymnasium will serve as a library to ensure access to information.', for the predicate 'serve', how much does the argument 'library' fit the role of Location? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "High"}
# responce:  {"Fit score": "High"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space capable of being repurposed or used for an activity different from its original function, specifically to facilitate access to information or act as a place for reading and studying.'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, and it implies a setting conducive to study and learning."}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the above, how will the argument \'library\' fit the Location role for the predicate \'serve\'? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' fits the Location role for the predicate 'serve' by indicating that the gymnasium will be repurposed as a space for accessing information, akin to the functions of a library, thus making it a suitable location for this new role."}]
# categorical_with_senetence:  0.75
# user_prompt :  Given the following sentence 'In times of crisis, the school's gymnasium will serve as a library to ensure access to information.', for the predicate 'serve', how much does the argument 'library' fit the role of Location? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "0.9"}
# responce:  {"Fit score": "0.9"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space capable of being repurposed or used for an activity different from its original function, specifically to facilitate access to information or act as a place for reading and studying.'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, and it implies a setting conducive to study and learning."}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the above, how will the argument \'library\' fit the Location role for the predicate \'serve\'? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' fits the Location role for the predicate 'serve' by indicating that the gymnasium will be repurposed as a space for accessing information, akin to the functions of a library, thus making it a suitable location for this new role."}]
# numerical_with_senetence:  0.9
# After Poping the semantic:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space capable of being repurposed or used for an activity different from its original function, specifically to facilitate access to information or act as a place for reading and studying.'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, and it implies a setting conducive to study and learning."}]
# check_semantic_prompt :  Is the given sentence 'The old train station has been renovated to serve as a library, blending history with literacy.' semantically coherent and containing the predicate 'serve' and the argument 'library' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value 'Yes' or 'No', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.
# response_check_semantic:  {"Is Semantically Coherent": "Yes"}
# responce:  {"Is Semantically Coherent": "Yes"}
# is_semantic:  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space capable of being repurposed or used for an activity different from its original function, specifically to facilitate access to information or act as a place for reading and studying.'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, and it implies a setting conducive to study and learning."}, {'role': 'user', 'content': 'Is the given sentence \'The old train station has been renovated to serve as a library, blending history with literacy.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space capable of being repurposed or used for an activity different from its original function, specifically to facilitate access to information or act as a place for reading and studying.'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, and it implies a setting conducive to study and learning."}, {'role': 'user', 'content': 'Is the given sentence \'The old train station has been renovated to serve as a library, blending history with literacy.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# response_reason:
#  {"Response": "The Location role should have properties indicating it is a physical space that has been adapted or repurposed, capable of housing books and resources for reading and study, and it should be suitable for public access and use as a center for learning and literacy."}
# responce:  {"Response": "The Location role should have properties indicating it is a physical space that has been adapted or repurposed, capable of housing books and resources for reading and study, and it should be suitable for public access and use as a center for learning and literacy."}
# join reasons:  ['serve', 'library', 'Location', 'The Location role should have properties indicating it is a physical space that has been adapted or repurposed, capable of housing books and resources for reading and study, and it should be suitable for public access and use as a center for learning and literacy.']
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space capable of being repurposed or used for an activity different from its original function, specifically to facilitate access to information or act as a place for reading and studying.'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, and it implies a setting conducive to study and learning."}, {'role': 'user', 'content': 'Is the given sentence \'The old train station has been renovated to serve as a library, blending history with literacy.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'The old train station has been renovated to serve as a library, blending history with literacy.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space that has been adapted or repurposed, capable of housing books and resources for reading and study, and it should be suitable for public access and use as a center for learning and literacy.'}]
# response_reason:
#  {"Response": "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, serving as a hub for learning, and potentially preserving or promoting historical and cultural knowledge."}
# responce:  {"Response": "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, serving as a hub for learning, and potentially preserving or promoting historical and cultural knowledge."}
# join reasons:  ['serve', 'library', 'Location', 'The Location role should have properties indicating it is a physical space that has been adapted or repurposed, capable of housing books and resources for reading and study, and it should be suitable for public access and use as a center for learning and literacy.', "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, serving as a hub for learning, and potentially preserving or promoting historical and cultural knowledge."]
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space capable of being repurposed or used for an activity different from its original function, specifically to facilitate access to information or act as a place for reading and studying.'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, and it implies a setting conducive to study and learning."}, {'role': 'user', 'content': 'Is the given sentence \'The old train station has been renovated to serve as a library, blending history with literacy.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'The old train station has been renovated to serve as a library, blending history with literacy.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space that has been adapted or repurposed, capable of housing books and resources for reading and study, and it should be suitable for public access and use as a center for learning and literacy.'}, {'role': 'user', 'content': 'In the following sentence: \'The old train station has been renovated to serve as a library, blending history with literacy.\', given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value t ...
# response_reason:
#  The argument 'library' fits the Location role for the predicate 'serve' as it describes the new function or purpose of a physical space, specifically the old train station being repurposed to facilitate access to books, learning resources, and literacy activities, thereby serving the community in a new capacity.
# The argument 'library' fits the Location role for the predicate 'serve' as it describes the new function or purpose of a physical space, specifically the old train station being repurposed to facilitate access to books, learning resources, and literacy activities, thereby serving the community in a new capacity.
# {"Response":"The argument 'library' fits the Location role for the predicate 'serve' as it describes the new function or purpose of a physical space, specifically the old train station being repurposed to facilitate access to books, learning resources, and literacy activities, thereby serving the community in a new capacity. "}
# responce:  {"Response":"The argument 'library' fits the Location role for the predicate 'serve' as it describes the new function or purpose of a physical space, specifically the old train station being repurposed to facilitate access to books, learning resources, and literacy activities, thereby serving the community in a new capacity. "}
# join reasons:  ['serve', 'library', 'Location', 'The Location role should have properties indicating it is a physical space that has been adapted or repurposed, capable of housing books and resources for reading and study, and it should be suitable for public access and use as a center for learning and literacy.', "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, serving as a hub for learning, and potentially preserving or promoting historical and cultural knowledge.", "The argument 'library' fits the Location role for the predicate 'serve' as it describes the new function or purpose of a physical space, specifically the old train station being repurposed to facilitate access to books, learning resources, and literacy activities, thereby serving the community in a new capacity. "]
# user_prompt :  Given the following sentence 'The old train station has been renovated to serve as a library, blending history with literacy.', for the predicate 'serve', how much does the argument 'library' fit the role of Location? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "High"}
# responce:  {"Fit score": "High"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space capable of being repurposed or used for an activity different from its original function, specifically to facilitate access to information or act as a place for reading and studying.'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, and it implies a setting conducive to study and learning."}, {'role': 'user', 'content': 'Is the given sentence \'The old train station has been renovated to serve as a library, blending history with literacy.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'The old train station has been renovated to serve as a library, blending history with literacy.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space that has been adapted or repurposed, capable of housing books and resources for reading and study, and it should be suitable for public access and use as a center for learning and literacy.'}, {'role': 'user', 'content': 'In the following sentence: \'The old train station has been renovated to serve as a library, blending history with literacy.\', given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that  ...
# categorical_with_senetence:  0.75
# user_prompt :  Given the following sentence 'The old train station has been renovated to serve as a library, blending history with literacy.', for the predicate 'serve', how much does the argument 'library' fit the role of Location? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "1.0"}
# responce:  {"Fit score": "1.0"}
# ...
# {"Response":"The argument 'library' fits the Location role for the predicate 'serve' by being the intended function or purpose that the vacant lot will be transformed into, indicating that the space will be developed into a place where library services are provided, thus embodying the characteristics of a library as a physical location for learning and access to information. "}
# responce:  {"Response":"The argument 'library' fits the Location role for the predicate 'serve' by being the intended function or purpose that the vacant lot will be transformed into, indicating that the space will be developed into a place where library services are provided, thus embodying the characteristics of a library as a physical location for learning and access to information. "}
# join reasons:  ['serve', 'library', 'Location', 'The Location role should have properties indicating it is an open, undeveloped space capable of being transformed into a structured environment for housing books and resources, conducive to reading, studying, and community engagement.', "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, serving as a center for learning, education, and community engagement.", "The argument 'library' fits the Location role for the predicate 'serve' by being the intended function or purpose that the vacant lot will be transformed into, indicating that the space will be developed into a place where library services are provided, thus embodying the characteristics of a library as a physical location for learning and access to information. "]
# user_prompt :  Given the following sentence 'The vacant lot next to the park will soon serve as a library, providing a new hub for learning.', for the predicate 'serve', how much does the argument 'library' fit the role of Location? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "High"}
# responce:  {"Fit score": "High"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space capable of being repurposed or used for an activity different from its original function, specifically to facilitate access to information or act as a place for reading and studying.'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, and it implies a setting conducive to study and learning."}, {'role': 'user', 'content': 'Is the given sentence \'The old train station has been renovated to serve as a library, blending history with literacy.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'The old train station has been renovated to serve as a library, blending history with literacy.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space that has been adapted or repurposed, capable of housing books and resources for reading and study, and it should be suitable for public access and use as a center for learning and literacy.'}, {'role': 'user', 'content': 'In the following sentence: \'The old train station has been renovated to serve as a library, blending history with literacy.\', given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that  ...
# categorical_with_senetence:  0.75
# user_prompt :  Given the following sentence 'The vacant lot next to the park will soon serve as a library, providing a new hub for learning.', for the predicate 'serve', how much does the argument 'library' fit the role of Location? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "0.9"}
# responce:  {"Fit score": "0.9"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space capable of being repurposed or used for an activity different from its original function, specifically to facilitate access to information or act as a place for reading and studying.'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, and it implies a setting conducive to study and learning."}, {'role': 'user', 'content': 'Is the given sentence \'The old train station has been renovated to serve as a library, blending history with literacy.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'The old train station has been renovated to serve as a library, blending history with literacy.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space that has been adapted or repurposed, capable of housing books and resources for reading and study, and it should be suitable for public access and use as a center for learning and literacy.'}, {'role': 'user', 'content': 'In the following sentence: \'The old train station has been renovated to serve as a library, blending history with literacy.\', given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that  ...
# numerical_with_senetence:  0.9
# After Poping the semantic:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space capable of being repurposed or used for an activity different from its original function, specifically to facilitate access to information or act as a place for reading and studying.'}, {'role': 'user', 'content': 'In the following sentence: \'In times of crisis, the school\'s gymnasium will serve as a library to ensure access to information.\', given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'library' has properties of being a place for accessing, reading, and borrowing books and other informational resources, and it implies a setting conducive to study and learning."}, {'role': 'user', 'content': 'Is the given sentence \'The old train station has been renovated to serve as a library, blending history with literacy.\' semantically coherent and containing the predicate \'serve\' and the argument \'library\' in the role of Location? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'The old train station has been renovated to serve as a library, blending history with literacy.\', given the predicate \'serve\', what properties should the Location role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The Location role should have properties indicating it is a physical space that has been adapted or repurposed, capable of housing books and resources for reading and study, and it should be suitable for public access and use as a center for learning and literacy.'}, {'role': 'user', 'content': 'In the following sentence: \'The old train station has been renovated to serve as a library, blending history with literacy.\', given the predicate \'serve\', and the argument \'library\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for t ...
# result1:  ['serve', 'library', '', 0.9, "In times of crisis, the school's gymnasium will serve as a library to ensure access to information.", 0.9, 'The old train station has been renovated to serve as a library, blending history with literacy.', 1.0, 'A mobile van has been outfitted to serve as a library, bringing books to remote areas.', 0.9, 'The vacant lot next to the park will soon serve as a library, providing a new hub for learning.', 0.9, '2.4', 0.92]
# result2:  ['serve', 'library', '', 0.75, "In times of crisis, the school's gymnasium will serve as a library to ensure access to information.", 0.75, 'The old train station has been renovated to serve as a library, blending history with literacy.', 0.75, 'A mobile van has been outfitted to serve as a library, bringing books to remote areas.', 0.75, 'The vacant lot next to the park will soon serve as a library, providing a new hub for learning.', 0.75, '2.4', 0.75]
# ---------------------DONE----------------------

# %% [markdown]
# - For ferretti Instrument

# %%
experiments.exp_reasoning_gen_sentences_ferretti('ferretti_instrument.csv','Instrument', llama2_model, model_name)

# %% [markdown]
# - For Pado

# %%
experiments.exp_reasoning_gen_sentences_other('pado_plausibility_pb.txt', llama2_model ,model_name)
# Out:
# New Record :  advise banker ARG0
# The sentences are:  ['The banker advised the client on the best investment strategies.', 'A banker advised her to reconsider the loan terms before proceeding.', 'Before making any decisions, the banker advised looking into more sustainable financial plans.', 'Upon reviewing her account, the banker advised increasing the savings contributions.', 'The banker advised against withdrawing the fixed deposit prematurely.']
# check_semantic_prompt :  Is the given sentence 'The banker advised the client on the best investment strategies.' semantically coherent and containing the predicate 'advise' and the argument 'banker' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value 'Yes' or 'No', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.
# response_check_semantic:  {"Is Semantically Coherent": "Yes"}
# responce:  {"Is Semantically Coherent": "Yes"}
# is_semantic:  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The banker advised the client on the best investment strategies.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The banker advised the client on the best investment strategies.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# response_reason:
#  {"Response": "Agent or person giving advice"}
# responce:  {"Response": "Agent or person giving advice"}
# join reasons:  ['advise', 'banker', 'ARG0', 'Agent or person giving advice']
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The banker advised the client on the best investment strategies.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'The banker advised the client on the best investment strategies.\', given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Agent or person giving advice'}]
# response_reason:
#  {"Response": "Agent or person giving advice"}
# responce:  {"Response": "Agent or person giving advice"}
# join reasons:  ['advise', 'banker', 'ARG0', 'Agent or person giving advice', 'Agent or person giving advice']
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The banker advised the client on the best investment strategies.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'The banker advised the client on the best investment strategies.\', given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Agent or person giving advice'}, {'role': 'user', 'content': 'In the following sentence: \'The banker advised the client on the best investment strategies.\', given the predicate \'advise\', and the argument \'banker\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Agent or person giving advice'}]
# response_reason:
#  {"Response": "Perfectly fits as the advisor or the one giving advice"}
# responce:  {"Response": "Perfectly fits as the advisor or the one giving advice"}
# join reasons:  ['advise', 'banker', 'ARG0', 'Agent or person giving advice', 'Agent or person giving advice', 'Perfectly fits as the advisor or the one giving advice']
# user_prompt :  Given the following sentence 'The banker advised the client on the best investment strategies.', for the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "Near-Perfect"}
# responce:  {"Fit score": "Near-Perfect"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The banker advised the client on the best investment strategies.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'The banker advised the client on the best investment strategies.\', given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Agent or person giving advice'}, {'role': 'user', 'content': 'In the following sentence: \'The banker advised the client on the best investment strategies.\', given the predicate \'advise\', and the argument \'banker\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Agent or person giving advice'}, {'role': 'user', 'content': 'In the following sentence: \'The banker advised the client on the best investment strategies.\', given the above, how will the argument \'banker\' fit the PropBank ARG0 role for the predicate \'advise\'? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Perfectly fits as the advisor or the one giving advice'}]
# categorical_with_senetence:  1.0
# user_prompt :  Given the following sentence 'The banker advised the client on the best investment strategies.', for the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "1.0"}
# responce:  {"Fit score": "1.0"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The banker advised the client on the best investment strategies.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'The banker advised the client on the best investment strategies.\', given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Agent or person giving advice'}, {'role': 'user', 'content': 'In the following sentence: \'The banker advised the client on the best investment strategies.\', given the predicate \'advise\', and the argument \'banker\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Agent or person giving advice'}, {'role': 'user', 'content': 'In the following sentence: \'The banker advised the client on the best investment strategies.\', given the above, how will the argument \'banker\' fit the PropBank ARG0 role for the predicate \'advise\'? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Perfectly fits as the advisor or the one giving advice'}]
# numerical_with_senetence:  1.0
# After Poping the semantic:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# check_semantic_prompt :  Is the given sentence 'A banker advised her to reconsider the loan terms before proceeding.' semantically coherent and containing the predicate 'advise' and the argument 'banker' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value 'Yes' or 'No', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.
# response_check_semantic:  {"Is Semantically Coherent": "Yes"}
# responce:  {"Is Semantically Coherent": "Yes"}
# is_semantic:  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'A banker advised her to reconsider the loan terms before proceeding.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'A banker advised her to reconsider the loan terms before proceeding.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# response_reason:
#  {"Response": "Agent or causer of the action, typically the advisor or person giving advice"}
# responce:  {"Response": "Agent or causer of the action, typically the advisor or person giving advice"}
# join reasons:  ['advise', 'banker', 'ARG0', 'Agent or causer of the action, typically the advisor or person giving advice']
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'A banker advised her to reconsider the loan terms before proceeding.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'A banker advised her to reconsider the loan terms before proceeding.\', given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Agent or causer of the action, typically the advisor or person giving advice'}]
# response_reason:
#  {"Response": "Agent or causer of the action, typically the advisor or person giving advice"}
# responce:  {"Response": "Agent or causer of the action, typically the advisor or person giving advice"}
# join reasons:  ['advise', 'banker', 'ARG0', 'Agent or causer of the action, typically the advisor or person giving advice', 'Agent or causer of the action, typically the advisor or person giving advice']
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'A banker advised her to reconsider the loan terms before proceeding.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'A banker advised her to reconsider the loan terms before proceeding.\', given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Agent or causer of the action, typically the advisor or person giving advice'}, {'role': 'user', 'content': 'In the following sentence: \'A banker advised her to reconsider the loan terms before proceeding.\', given the predicate \'advise\', and the argument \'banker\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Agent or causer of the action, typically the advisor or person giving advice'}]
# response_reason:
#  {"Response": "The argument 'banker' fits the PropBank ARG0 role for the predicate 'advise' as the agent or causer of the action, being the one who gives the advice."}
# responce:  {"Response": "The argument 'banker' fits the PropBank ARG0 role for the predicate 'advise' as the agent or causer of the action, being the one who gives the advice."}
# join reasons:  ['advise', 'banker', 'ARG0', 'Agent or causer of the action, typically the advisor or person giving advice', 'Agent or causer of the action, typically the advisor or person giving advice', "The argument 'banker' fits the PropBank ARG0 role for the predicate 'advise' as the agent or causer of the action, being the one who gives the advice."]
# user_prompt :  Given the following sentence 'A banker advised her to reconsider the loan terms before proceeding.', for the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "Near-Perfect"}
# responce:  {"Fit score": "Near-Perfect"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'A banker advised her to reconsider the loan terms before proceeding.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'A banker advised her to reconsider the loan terms before proceeding.\', given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Agent or causer of the action, typically the advisor or person giving advice'}, {'role': 'user', 'content': 'In the following sentence: \'A banker advised her to reconsider the loan terms before proceeding.\', given the predicate \'advise\', and the argument \'banker\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Agent or causer of the action, typically the advisor or person giving advice'}, {'role': 'user', 'content': 'In the following sentence: \'A banker advised her to reconsider the loan terms before proceeding.\', given the above, how will the argument \'banker\' fit the PropBank ARG0 role for the predicate \'advise\'? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' fits the PropBank ARG0 role for the predicate 'advise' as the agent or causer of the action, being the one who gives the advice."}]
# categorical_with_senetence:  1.0
# user_prompt :  Given the following sentence 'A banker advised her to reconsider the loan terms before proceeding.', for the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "1.0"}
# responce:  {"Fit score": "1.0"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'A banker advised her to reconsider the loan terms before proceeding.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'A banker advised her to reconsider the loan terms before proceeding.\', given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Agent or causer of the action, typically the advisor or person giving advice'}, {'role': 'user', 'content': 'In the following sentence: \'A banker advised her to reconsider the loan terms before proceeding.\', given the predicate \'advise\', and the argument \'banker\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Agent or causer of the action, typically the advisor or person giving advice'}, {'role': 'user', 'content': 'In the following sentence: \'A banker advised her to reconsider the loan terms before proceeding.\', given the above, how will the argument \'banker\' fit the PropBank ARG0 role for the predicate \'advise\'? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' fits the PropBank ARG0 role for the predicate 'advise' as the agent or causer of the action, being the one who gives the advice."}]
# numerical_with_senetence:  1.0
# After Poping the semantic:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# check_semantic_prompt :  Is the given sentence 'Before making any decisions, the banker advised looking into more sustainable financial plans.' semantically coherent and containing the predicate 'advise' and the argument 'banker' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value 'Yes' or 'No', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.
# response_check_semantic:  {"Is Semantically Coherent": "Yes"}
# responce:  {"Is Semantically Coherent": "Yes"}
# is_semantic:  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'Before making any decisions, the banker advised looking into more sustainable financial plans.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'Before making any decisions, the banker advised looking into more sustainable financial plans.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# response_reason:
#  {"Response": "The ARG0 of 'advise' should be the advisor or the entity giving advice."}
# responce:  {"Response": "The ARG0 of 'advise' should be the advisor or the entity giving advice."}
# join reasons:  ['advise', 'banker', 'ARG0', "The ARG0 of 'advise' should be the advisor or the entity giving advice."]
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'Before making any decisions, the banker advised looking into more sustainable financial plans.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'Before making any decisions, the banker advised looking into more sustainable financial plans.\', given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The ARG0 of 'advise' should be the advisor or the entity giving advice."}]
# response_reason:
#  {"Response": "The argument 'banker' serves as the advisor or entity giving advice."}
# responce:  {"Response": "The argument 'banker' serves as the advisor or entity giving advice."}
# join reasons:  ['advise', 'banker', 'ARG0', "The ARG0 of 'advise' should be the advisor or the entity giving advice.", "The argument 'banker' serves as the advisor or entity giving advice."]
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'Before making any decisions, the banker advised looking into more sustainable financial plans.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'Before making any decisions, the banker advised looking into more sustainable financial plans.\', given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The ARG0 of 'advise' should be the advisor or the entity giving advice."}, {'role': 'user', 'content': 'In the following sentence: \'Before making any decisions, the banker advised looking into more sustainable financial plans.\', given the predicate \'advise\', and the argument \'banker\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' serves as the advisor or entity giving advice."}]
# response_reason:
#  {"Response": "The argument 'banker' fits the PropBank ARG0 role for the predicate 'advise' as the advisor or entity giving advice."}
# responce:  {"Response": "The argument 'banker' fits the PropBank ARG0 role for the predicate 'advise' as the advisor or entity giving advice."}
# join reasons:  ['advise', 'banker', 'ARG0', "The ARG0 of 'advise' should be the advisor or the entity giving advice.", "The argument 'banker' serves as the advisor or entity giving advice.", "The argument 'banker' fits the PropBank ARG0 role for the predicate 'advise' as the advisor or entity giving advice."]
# user_prompt :  Given the following sentence 'Before making any decisions, the banker advised looking into more sustainable financial plans.', for the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "Near-Perfect"}
# responce:  {"Fit score": "Near-Perfect"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'Before making any decisions, the banker advised looking into more sustainable financial plans.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'Before making any decisions, the banker advised looking into more sustainable financial plans.\', given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The ARG0 of 'advise' should be the advisor or the entity giving advice."}, {'role': 'user', 'content': 'In the following sentence: \'Before making any decisions, the banker advised looking into more sustainable financial plans.\', given the predicate \'advise\', and the argument \'banker\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' serves as the advisor or entity giving advice."}, {'role': 'user', 'content': 'In the following sentence: \'Before making any decisions, the banker advised looking into more sustainable financial plans.\', given the above, how will the argument \'banker\' fit the PropBank ARG0 role for the predicate \'advise\'? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' fits the PropBank ARG0 role for the predicate 'advise' as the advisor or entity giving advice."}]
# categorical_with_senetence:  1.0
# user_prompt :  Given the following sentence 'Before making any decisions, the banker advised looking into more sustainable financial plans.', for the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "1.0"}
# responce:  {"Fit score": "1.0"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'Before making any decisions, the banker advised looking into more sustainable financial plans.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'Before making any decisions, the banker advised looking into more sustainable financial plans.\', given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The ARG0 of 'advise' should be the advisor or the entity giving advice."}, {'role': 'user', 'content': 'In the following sentence: \'Before making any decisions, the banker advised looking into more sustainable financial plans.\', given the predicate \'advise\', and the argument \'banker\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' serves as the advisor or entity giving advice."}, {'role': 'user', 'content': 'In the following sentence: \'Before making any decisions, the banker advised looking into more sustainable financial plans.\', given the above, how will the argument \'banker\' fit the PropBank ARG0 role for the predicate \'advise\'? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' fits the PropBank ARG0 role for the predicate 'advise' as the advisor or entity giving advice."}]
# numerical_with_senetence:  1.0
# After Poping the semantic:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# check_semantic_prompt :  Is the given sentence 'Upon reviewing her account, the banker advised increasing the savings contributions.' semantically coherent and containing the predicate 'advise' and the argument 'banker' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value 'Yes' or 'No', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.
# response_check_semantic:  {"Is Semantically Coherent": "Yes"}
# responce:  {"Is Semantically Coherent": "Yes"}
# is_semantic:  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'Upon reviewing her account, the banker advised increasing the savings contributions.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'Upon reviewing her account, the banker advised increasing the savings contributions.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# response_reason:
#  {"Response": "The ARG0 role for the predicate 'advise' should be the advisor or the entity giving advice."}
# responce:  {"Response": "The ARG0 role for the predicate 'advise' should be the advisor or the entity giving advice."}
# join reasons:  ['advise', 'banker', 'ARG0', "The ARG0 role for the predicate 'advise' should be the advisor or the entity giving advice."]
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'Upon reviewing her account, the banker advised increasing the savings contributions.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'Upon reviewing her account, the banker advised increasing the savings contributions.\', given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The ARG0 role for the predicate 'advise' should be the advisor or the entity giving advice."}]
# response_reason:
#  {"Response": "The argument 'banker' has the properties of being the advisor or entity giving advice, having the authority or expertise to make recommendations, and performing the action of reviewing an account which leads to the advice given."}
# responce:  {"Response": "The argument 'banker' has the properties of being the advisor or entity giving advice, having the authority or expertise to make recommendations, and performing the action of reviewing an account which leads to the advice given."}
# join reasons:  ['advise', 'banker', 'ARG0', "The ARG0 role for the predicate 'advise' should be the advisor or the entity giving advice.", "The argument 'banker' has the properties of being the advisor or entity giving advice, having the authority or expertise to make recommendations, and performing the action of reviewing an account which leads to the advice given."]
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'Upon reviewing her account, the banker advised increasing the savings contributions.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'Upon reviewing her account, the banker advised increasing the savings contributions.\', given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The ARG0 role for the predicate 'advise' should be the advisor or the entity giving advice."}, {'role': 'user', 'content': 'In the following sentence: \'Upon reviewing her account, the banker advised increasing the savings contributions.\', given the predicate \'advise\', and the argument \'banker\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' has the properties of being the advisor or entity giving advice, having the authority or expertise to make recommendations, and performing the action of reviewing an account which leads to the advice given."}]
# response_reason:
#  {"Response": "The argument 'banker' fits the PropBank ARG0 role for the predicate 'advise' as the entity giving advice, demonstrating authority or expertise in financial matters, and initiating the action of advising based on an account review."}
# responce:  {"Response": "The argument 'banker' fits the PropBank ARG0 role for the predicate 'advise' as the entity giving advice, demonstrating authority or expertise in financial matters, and initiating the action of advising based on an account review."}
# join reasons:  ['advise', 'banker', 'ARG0', "The ARG0 role for the predicate 'advise' should be the advisor or the entity giving advice.", "The argument 'banker' has the properties of being the advisor or entity giving advice, having the authority or expertise to make recommendations, and performing the action of reviewing an account which leads to the advice given.", "The argument 'banker' fits the PropBank ARG0 role for the predicate 'advise' as the entity giving advice, demonstrating authority or expertise in financial matters, and initiating the action of advising based on an account review."]
# ...
# numerical_with_senetence:  1.0
# After Poping the semantic:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# check_semantic_prompt :  Is the given sentence 'The banker advised against withdrawing the fixed deposit prematurely.' semantically coherent and containing the predicate 'advise' and the argument 'banker' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value 'Yes' or 'No', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.
# response_check_semantic:  {"Is Semantically Coherent": "Yes"}
# responce:  {"Is Semantically Coherent": "Yes"}
# is_semantic:  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The banker advised against withdrawing the fixed deposit prematurely.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The banker advised against withdrawing the fixed deposit prematurely.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}]
# response_reason:
#  {"Response": "The entity giving advice"}
# responce:  {"Response": "The entity giving advice"}
# join reasons:  ['advise', 'banker', 'ARG0', 'The entity giving advice']
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The banker advised against withdrawing the fixed deposit prematurely.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'The banker advised against withdrawing the fixed deposit prematurely.\', given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The entity giving advice'}]
# response_reason:
#  {"Response": "The argument 'banker' is the entity giving advice, indicating a role of agency and expertise in financial matters."}
# responce:  {"Response": "The argument 'banker' is the entity giving advice, indicating a role of agency and expertise in financial matters."}
# join reasons:  ['advise', 'banker', 'ARG0', 'The entity giving advice', "The argument 'banker' is the entity giving advice, indicating a role of agency and expertise in financial matters."]
# Before Adding Reason /n [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The banker advised against withdrawing the fixed deposit prematurely.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'The banker advised against withdrawing the fixed deposit prematurely.\', given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The entity giving advice'}, {'role': 'user', 'content': 'In the following sentence: \'The banker advised against withdrawing the fixed deposit prematurely.\', given the predicate \'advise\', and the argument \'banker\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' is the entity giving advice, indicating a role of agency and expertise in financial matters."}]
# response_reason:
#  {"Response": "The argument 'banker' fits the PropBank ARG0 role for the predicate 'advise' as the advisor, perfectly aligning with the role's requirement for an agent who gives advice."}
# responce:  {"Response": "The argument 'banker' fits the PropBank ARG0 role for the predicate 'advise' as the advisor, perfectly aligning with the role's requirement for an agent who gives advice."}
# join reasons:  ['advise', 'banker', 'ARG0', 'The entity giving advice', "The argument 'banker' is the entity giving advice, indicating a role of agency and expertise in financial matters.", "The argument 'banker' fits the PropBank ARG0 role for the predicate 'advise' as the advisor, perfectly aligning with the role's requirement for an agent who gives advice."]
# user_prompt :  Given the following sentence 'The banker advised against withdrawing the fixed deposit prematurely.', for the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is one of 'Near-Perfect', 'High', 'Medium', 'Low' or 'Near-Impossible', according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "Near-Perfect"}
# responce:  {"Fit score": "Near-Perfect"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The banker advised against withdrawing the fixed deposit prematurely.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'The banker advised against withdrawing the fixed deposit prematurely.\', given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The entity giving advice'}, {'role': 'user', 'content': 'In the following sentence: \'The banker advised against withdrawing the fixed deposit prematurely.\', given the predicate \'advise\', and the argument \'banker\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' is the entity giving advice, indicating a role of agency and expertise in financial matters."}, {'role': 'user', 'content': 'In the following sentence: \'The banker advised against withdrawing the fixed deposit prematurely.\', given the above, how will the argument \'banker\' fit the PropBank ARG0 role for the predicate \'advise\'? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' fits the PropBank ARG0 role for the predicate 'advise' as the advisor, perfectly aligning with the role's requirement for an agent who gives advice."}]
# categorical_with_senetence:  1.0
# user_prompt :  Given the following sentence 'The banker advised against withdrawing the fixed deposit prematurely.', for the predicate 'advise', how much does the argument 'banker' fit the role of ARG0? Reply only with a valid JSON dictionary containing the key "Fit score" and a value that is a float number from 0 to 1, according to the following structure {"Fit score": String}. Avoid adding any text outside this JSON dictionary.
# response_fit_score:  {"Fit score": "1.0"}
# responce:  {"Fit score": "1.0"}
# conversation after: [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}, {'role': 'user', 'content': 'Is the given sentence \'The banker advised against withdrawing the fixed deposit prematurely.\' semantically coherent and containing the predicate \'advise\' and the argument \'banker\' in the role of ARG0? Reply only with a valid JSON dictionary containing the key "Is Semantically Coherent" and a value \'Yes\' or \'No\', according to the following structure {"Is Semantically Coherent": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'Yes'}, {'role': 'user', 'content': 'In the following sentence: \'The banker advised against withdrawing the fixed deposit prematurely.\', given the predicate \'advise\', what properties should its PropBank ARG0 role have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': 'The entity giving advice'}, {'role': 'user', 'content': 'In the following sentence: \'The banker advised against withdrawing the fixed deposit prematurely.\', given the predicate \'advise\', and the argument \'banker\', what relevant properties does the argument have? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' is the entity giving advice, indicating a role of agency and expertise in financial matters."}, {'role': 'user', 'content': 'In the following sentence: \'The banker advised against withdrawing the fixed deposit prematurely.\', given the above, how will the argument \'banker\' fit the PropBank ARG0 role for the predicate \'advise\'? Reply only with a valid JSON dictionary containing the key "Response" and a value that is the answer for the question, according to the following structure {"Response": String}. Avoid adding any text outside this JSON dictionary.'}, {'role': 'assistant', 'content': "The argument 'banker' fits the PropBank ARG0 role for the predicate 'advise' as the advisor, perfectly aligning with the role's requirement for an agent who gives advice."}]
# numerical_with_senetence:  1.0
# After Poping the semantic:
#  [{'role': 'system', 'content': 'You are a linguist who understands semantic roles and can provide a rating on the semantic fit of predicate-arguments for a specific semantic role, given the predicate, the argument, and the semantic role.'}]
# result1:  ['advise', 'banker', 'ARG0', 'The banker advised the client on the best investment strategies.', 1.0, 'A banker advised her to reconsider the loan terms before proceeding.', 1.0, 'Before making any decisions, the banker advised looking into more sustainable financial plans.', 1.0, 'Upon reviewing her account, the banker advised increasing the savings contributions.', 1.0, 'The banker advised against withdrawing the fixed deposit prematurely.', 1.0, '6.0\n', 1.0]
# result2:  ['advise', 'banker', 'ARG0', 'The banker advised the client on the best investment strategies.', 1.0, 'A banker advised her to reconsider the loan terms before proceeding.', 1.0, 'Before making any decisions, the banker advised looking into more sustainable financial plans.', 1.0, 'Upon reviewing her account, the banker advised increasing the savings contributions.', 1.0, 'The banker advised against withdrawing the fixed deposit prematurely.', 1.0, '6.0\n', 1.0]
# ---------------------DONE----------------------

# %% [markdown]
# - For Mcrae

# %%
experiments.exp_reasoning_gen_sentences_other('mcrae_agent_patient_more.txt', llama2_model ,model_name)
